# %%
import numpy as np

# %%
mat = np.genfromtxt('./eval_matrix.csv', delimiter=',')

# %%
mat
# Out:
# array([[ 4.00478587,  4.14646947,  4.00003977,  4.41603138,  4.91793534,
#          5.12443293,  5.15512153,  4.61616264,  4.3154941 ,  4.24421509,
#          5.15940186,  5.20821533,  5.21544726,  5.20786378,  4.7076492 ,
#          4.21135768,  5.14390596,  5.17631204,  5.15838293,  5.17572086,
#          5.22449001,  4.67172649,  4.27171257,  5.07716967,  5.1877572 ,
#          5.16805416,  5.1628194 ,  5.19222097,  4.67153125,  4.23684887,
#          5.0805198 ],
#        [ 4.03846183,  3.97653177,  3.88986154,  4.29143869,  4.77063061,
#          4.96330713,  4.98038591,  4.49215661,  4.20039172,  4.13075516,
#          4.99643902,  5.040172  ,  5.05526259,  5.04293271,  4.59116202,
#          4.10060284,  4.97657188,  5.01342811,  4.99416458,  5.01566988,
#          5.057104  ,  4.54049046,  4.16167237,  4.91689085,  5.02363688,
#          5.00781866,  4.99792747,  5.02606312,  4.54062632,  4.12543409,
#          4.90860406],
# ...

# %%
import seaborn as sns

# %%
ax = sns.heatmap(mat)

# %%
import matplotlib.pyplot as plt

# %%
plt.show()

# %%
np.min(mat, axis=1)
# Out:
# array([ 4.00003977,  3.88986154,  3.87018513,  3.87538013,  3.96376314,
#         3.96595214,  3.96074047,  3.8315313 ,  3.90939088,  3.86453456,
#         4.16607871,  4.01409465,  4.01573899,  3.95686343,  3.85507089,
#         3.87310426,  3.91651926,  3.93931782,  3.97964285,  3.98676493,
#         3.94068583,  3.88467737,  3.91948748,  3.9408373 ,  3.96499827,
#         3.97955594,  3.96518137,  3.95612159,  3.88928871,  3.8522578 ,
#         3.9411668 ])

# %%
np.min(mat, axis=0)
# Out:
# array([ 3.94558892,  3.97408773,  3.8315313 ,  4.13434005,  4.54884732,
#         4.70223605,  4.71706742,  4.2820476 ,  4.08634485,  3.99018393,
#         4.71241548,  4.74980157,  4.76040385,  4.7555443 ,  4.39846356,
#         3.97708236,  4.69360073,  4.70968107,  4.70530669,  4.72870886,
#         4.74702676,  4.36969153,  4.03703504,  4.62956734,  4.74167355,
#         4.72491002,  4.70694309,  4.74781151,  4.36630218,  3.99298706,
#         4.62729106])

# %%
mat_minus = mat - np.min(mat, axis=0)

# %%
mat_minus[:, 1]
# Out:
# array([ 0.17238174,  0.00244403,  0.08533706,  0.04600076,  0.13529938,
#         0.13723274,  0.12927579,  0.        ,  0.08324328,  0.0354703 ,
#         0.33878154,  0.17977627,  0.18392438,  0.12234313,  0.02435541,
#         0.04521206,  0.08431687,  0.11253936,  0.15087246,  0.15937468,
#         0.10870304,  0.05805539,  0.09725993,  0.10677564,  0.13170956,
#         0.14214791,  0.13177436,  0.12945946,  0.05858657,  0.0201436 ,
#         0.11054121])

# %%
mat[:, 1] - np.min(mat[:, 1])
# Out:
# array([ 0.17238174,  0.00244403,  0.08533706,  0.04600076,  0.13529938,
#         0.13723274,  0.12927579,  0.        ,  0.08324328,  0.0354703 ,
#         0.33878154,  0.17977627,  0.18392438,  0.12234313,  0.02435541,
#         0.04521206,  0.08431687,  0.11253936,  0.15087246,  0.15937468,
#         0.10870304,  0.05805539,  0.09725993,  0.10677564,  0.13170956,
#         0.14214791,  0.13177436,  0.12945946,  0.05858657,  0.0201436 ,
#         0.11054121])

# %%
plt.clf()
ax = sns.heatmap(mat_minus)
plt.show()

# %%
losses = np.genfromtxt('/home/fan/work/results/sadHybridHumanPredictor/ensemble_losslog.csv', delimiter=',')

# %%
losses.shape
# Out:
# (43, 161)

# %%
losses = losses[:, :-1:5]

# %%
import pandas as pd
labels = ['ensemble']
for i in xrange(31):
    labels.append('model {}'.format(i + 1))

# %%
losses_df = pd.DataFrame(losses)

# %%
sns.plt.clf()
sns.plt.figure(figsize=(16, 7))
sns.plt.plot(losses_df)
sns.plt.legend(labels=labels, bbox_to_anchor=(1.01, 1), loc=2, ncol=2, borderaxespad=1, fontsize=16)
sns.plt.show()
